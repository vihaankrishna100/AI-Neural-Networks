# %% [markdown]
# <a href="https://colab.research.google.com/github/vihaankrishna100/AI-Neural-Networks/blob/main/MoviePanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/movies_metadata.csv').dropna(axis=1, how='all')
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage       id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862.0  tt0114709                en
# 1                                   NaN   8844.0  tt0113497                en
# ...

# %%
df.shape
# Out:
# (45453, 23)

# %%
df.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
budget_df = df[df[('budget')] > 1000000]
budget_df.shape
# Out:
# (7208, 23)

# %%
budget_lookup = budget_df.budget
budget_lookup.index = budget_df.title
budget_lookup['Dead Presidents']
# Out:
# 10000000

# %%
budget_df = budget_df.sort_values('title')
budget_lookup_as_and_bs = budget_df[budget_df["title"].str[0].isin(['A', 'B'])]
count = budget_lookup_as_and_bs.shape[0]
print(count)
# Out:
# 933

# %%
time_scheduler = df.set_index('runtime')
time_scheduler = time_scheduler[['title', 'release_date']]
time_scheduler.loc[154]
# Out:
#                                                      title release_date
# runtime
# 154.0                                         Pulp Fiction   1994-09-10
# 154.0                                             The Firm   1993-06-30
# 154.0                                     The Ruling Class   1972-09-13
# 154.0                                         Jackie Brown   1997-12-24
# 154.0                                     The Color Purple   1985-12-18
# 154.0                                        Amores perros   2000-06-16
# 154.0                               Va Savoir (Who Knows?)   2001-09-28
# 154.0                                     The Last Samurai   2003-12-05
# 154.0                                        Cold Mountain   2003-12-24
# 154.0                                   Sodom and Gomorrah   1962-01-01
# 154.0                                             Lord Jim   1965-02-15
# 154.0                           1492: Conquest of Paradise   1992-10-09
# ...

# %%
x=df.sort_values(by='runtime', ascending=False)
x.iloc[154]
# Out:
# belongs_to_collection                                                  NaN
# budget                                                                   0
# genres                   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# homepage                                                               NaN
# id                                                                  5998.0
# imdb_id                                                          tt0013086
# original_language                                                       de
# original_title                                     Dr. Mabuse, der Spieler
# overview                 Arch-criminal Dr. Mabuse, who is a master of d...
# popularity                                                        3.275117
# poster_path                               /9pK6ygSwdLdlx12PgUqLGiMFfnt.jpg
# production_companies               [{'name': 'Uco-Film GmbH', 'id': 2127}]
# ...

# %%
df_highly_voted = df[df.vote_count > 20]
df_high_rated = df_highly_voted[df_highly_voted.vote_average > 8]
df_high_rated[['title', 'vote_average', 'vote_count']]
# Out:
#                                title  vote_average  vote_count
# 46                             Se7en           8.1      5915.0
# 49                The Usual Suspects           8.1      3334.0
# 109                      Taxi Driver           8.1      2632.0
# 256                        Star Wars           8.1      6778.0
# 289           Leon: The Professional           8.2      4293.0
# ...                              ...           ...         ...
# 43576    Pink Floyd: Live at Pompeii           8.3        35.0
# 43962                    Life Cycles           8.8        27.0
# 44377  Hasan Minhaj: Homecoming King           8.1        22.0
# 44664  Black Mirror: White Christmas           8.3       211.0
# 45424                 In a Heartbeat           8.3       146.0
#
# [178 rows x 3 columns]

# %%
my_votes = {
    "Star Wars": 9,
    "Paris is Burning": 8,
    "Dead Poets Society": 7,
    "The Empire Strikes Back": 9.5,
    "The Shining": 8,
    "Return of the Jedi": 8,
    "1941": 8,
    "Forrest Gump": 7.5,
}

my_ratings = pd.Series(my_votes).rename("my_votes")
z = df_high_rated.set_index('title')
z = z.join(my_ratings).dropna(axis = 0)
z['percent_difference'] = 100 * ([z["vote_average"]- cv["my_votes"]]) / z["my_votes"]

# %%
df['revenue'].max()
# Out:
# 2787965087.0

# %%
movie_100 = df.sort_values(by='popularity', ascending=False)
movie_100.iloc[100]
# Out:
# belongs_to_collection    {'id': 295, 'name': 'Pirates of the Caribbean ...
# budget                                                           300000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                      http://disney.go.com/disneypictures/pirates/
# id                                                                   285.0
# imdb_id                                                          tt0449088
# original_language                                                       en
# original_title                    Pirates of the Caribbean: At World's End
# overview                 Captain Barbossa, long believed to be dead, ha...
# popularity                                                       31.363664
# poster_path                               /bXb00CkHqx7TPchTGG131sWV59y.jpg
# production_companies     [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ...

# %%
df['runtime'].mean()
# Out:
# 94.13477750979133
